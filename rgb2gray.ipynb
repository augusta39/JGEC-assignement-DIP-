# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from google.colab import files
from PIL import Image
from io import BytesIO
uploaded=files.upload()
im=Image.open(BytesIO(uploaded['1-2_31_real_I_00.png']))
plt.imshow(im)
plt.show()
# Out:
#      <input type="file" id="files-d8478dc0-35a1-4a59-84fd-fbd6a74f751f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d8478dc0-35a1-4a59-84fd-fbd6a74f751f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1-2_31_real_I_00.png to 1-2_31_real_I_00 (1).png

# %%
def rgb_to_gray(im):
  grayImage = np.zeros(im.shape)
R = np.array(im[:, :, 0])
G = np.array(im[:, :, 1]) 
B = np.array(im[:, :, 2]) 
R = (R *.299)
G = (G *.587)
B = (B *.114)
Avg = (R+G+B) 
grayImage = im 
for i in range(3):
  grayImage[:,:,i] = Avg
plt.imshow(grayImage)
plt.show()
